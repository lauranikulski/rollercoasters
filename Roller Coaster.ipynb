# %% [markdown]
# # Roller Coasters

# %% [markdown]
# 1.  Roller coasters are often split into two main categories based on their construction material: **wood** or **steel**. Rankings for the best wood and steel roller coasters from the 2013 to 2018 [Golden Ticket Awards](http://goldenticketawards.com) are provded in `'Golden_Ticket_Award_Winners_Wood.csv'` and `'Golden_Ticket_Award_Winners_Steel.csv'`, respectively. Load each csv into a DataFrame and inspect it to gain familiarity with the data.

# %%
# 1 
# Import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# load rankings data
wood = pd.read_csv('Golden_Ticket_Award_Winners_Wood.csv')
steel = pd.read_csv('Golden_Ticket_Award_Winners_Steel.csv')

# %%
wood.head()
# Out:
#    Rank          Name                       Park             Location  \
# 0     1  Boulder Dash             Lake Compounce       Bristol, Conn.
# 1     2       El Toro  Six Flags Great Adventure        Jackson, N.J.
# 2     3       Phoenix  Knoebels Amusement Resort        Elysburg, Pa.
# 3     4    The Voyage              Holiday World    Santa Claus, Ind.
# 4     5   Thunderhead                  Dollywood  Pigeon Forge, Tenn.
#
#            Supplier  Year Built  Points  Year of Rank
# 0               CCI        2000    1333          2013
# 1           Intamin        2006    1302          2013
# 2  Dinn/PTC-Schmeck        1985    1088          2013
# 3     Gravity Group        2006    1086          2013
# 4              GCII        2004     923          2013

# %%
steel.head()
# Out:
#    Rank                Name                        Park           Location  \
# 0     1    Millennium Force                 Cedar Point     Sandusky, Ohio
# 1     2             Bizarro       Six Flags New England      Agawam, Mass.
# 2     3  Expedition GeForce                Holiday Park  Hassloch, Germany
# 3     4               Nitro   Six Flags Great Adventure      Jackson, N.J.
# 4     5    Apollo’s Chariot  Busch Gardens Williamsburg  Williamsburg, Va.
#
#   Supplier  Year Built  Points  Year of Rank
# 0  Intamin        2000    1204          2013
# 1  Intamin        2000    1011          2013
# 2  Intamin        2001     598          2013
# 3      B&M        2001     596          2013
# 4      B&M        1999     542          2013

# %% [markdown]
# # Exploratory Data Analysis

# %%
wood.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          180 non-null    int64
#  1   Name          180 non-null    object
#  2   Park          180 non-null    object
#  3   Location      180 non-null    object
#  4   Supplier      179 non-null    object
#  5   Year Built    180 non-null    int64
#  6   Points        180 non-null    int64
#  7   Year of Rank  180 non-null    int64
# dtypes: int64(4), object(4)
# memory usage: 11.4+ KB

# %%
wood.describe(include='all')
# Out:
#               Rank     Name                       Park       Location  \
# count   180.000000      180                        180            180
# unique         NaN       61                         54             53
# top            NaN  El Toro  Knoebels Amusement Resort  Elysburg, Pa.
# freq           NaN        8                         12             12
# mean     22.127778      NaN                        NaN            NaN
# std      15.217246      NaN                        NaN            NaN
# min       1.000000      NaN                        NaN            NaN
# 25%       8.000000      NaN                        NaN            NaN
# 50%      20.500000      NaN                        NaN            NaN
# 75%      35.250000      NaN                        NaN            NaN
# max      50.000000      NaN                        NaN            NaN
#
#                    Supplier   Year Built       Points  Year of Rank
# count                   179   180.000000   180.000000    180.000000
# unique                   32          NaN          NaN           NaN
# top     Great Coasters Int.          NaN          NaN           NaN
# freq                     32          NaN          NaN           NaN
# mean                    NaN  1994.450000   392.388889   2016.500000
# std                     NaN    24.309061   381.816130      1.388299
# min                     NaN  1914.000000    66.000000   2013.000000
# 25%                     NaN  1994.000000   121.250000   2016.000000
# 50%                     NaN  2003.000000   213.500000   2017.000000
# 75%                     NaN  2009.000000   579.500000   2018.000000
# max                     NaN  2017.000000  1625.000000   2018.000000

# %%
wood.isna().sum()
# Out:
# Rank            0
# Name            0
# Park            0
# Location        0
# Supplier        1
# Year Built      0
# Points          0
# Year of Rank    0
# dtype: int64

# %%
wood.duplicated().sum()
# Out:
# 0

# %%
wood[wood.isnull().any(axis=1)]
# Out:
#      Rank          Name            Park      Location Supplier  Year Built  \
# 125    46  Grizzly (KD)  Kings Dominion  Doswell, Va.      NaN        1982
#
#      Points  Year of Rank
# 125      81          2017

# %%
steel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          180 non-null    int64
#  1   Name          180 non-null    object
#  2   Park          180 non-null    object
#  3   Location      180 non-null    object
#  4   Supplier      180 non-null    object
#  5   Year Built    180 non-null    int64
#  6   Points        180 non-null    int64
#  7   Year of Rank  180 non-null    int64
# dtypes: int64(4), object(4)
# memory usage: 11.4+ KB

# %%
steel.describe(include='all')
# Out:
#               Rank     Name         Park        Location Supplier  \
# count   180.000000      180          180             180      180
# unique         NaN       63           36              36       15
# top            NaN  Goliath  Cedar Point  Sandusky, Ohio      B&M
# freq           NaN        8           19              19       77
# mean     22.127778      NaN          NaN             NaN      NaN
# std      15.186377      NaN          NaN             NaN      NaN
# min       1.000000      NaN          NaN             NaN      NaN
# 25%       8.000000      NaN          NaN             NaN      NaN
# 50%      20.500000      NaN          NaN             NaN      NaN
# 75%      35.250000      NaN          NaN             NaN      NaN
# max      50.000000      NaN          NaN             NaN      NaN
#
#          Year Built       Points  Year of Rank
# count    180.000000   180.000000    180.000000
# unique          NaN          NaN           NaN
# top             NaN          NaN           NaN
# freq            NaN          NaN           NaN
# mean    2004.655556   325.433333   2016.500000
# std        9.511723   279.650322      1.388299
# min     1976.000000    59.000000   2013.000000
# 25%     2000.000000   112.250000   2016.000000
# 50%     2006.000000   246.000000   2017.000000
# 75%     2012.000000   427.000000   2018.000000
# max     2018.000000  1354.000000   2018.000000

# %%
steel[steel.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Park, Location, Supplier, Year Built, Points, Year of Rank]
# Index: []

# %%
steel.duplicated().sum()
# Out:
# 0

# %% [markdown]
# 2. Write a function that will plot the ranking of a given roller coaster over time as a line. Your function should take a roller coaster's name and a ranking DataFrame as arguments. Make sure to include informative labels that describe your visualization.
#
#    Call your function with `"El Toro"` as the roller coaster name and the wood ranking DataFrame. What issue do you notice? Update your function with an additional argument to alleviate the problem, and retest your function.

# %%
def ranking_over_time(my_frame, my_rollercoaster, my_park): 
  my_roller_ranking = my_frame[(my_frame.Name == my_rollercoaster) & (my_frame.Park == my_park)]
  plt.figure(figsize=(15, 8))
  x = my_roller_ranking['Year of Rank']
  y = my_roller_ranking.Points
  plt.plot(x, y, color='Indianred', linestyle='--', marker='o')
  sns.set_style('whitegrid')
  plt.xlabel('Year')
  plt.ylabel('Ranking by points')
  plt.title(f'{my_rollercoaster} ranking over time')
  plt.legend([f'{my_rollercoaster} '], loc=1)
  
  plt.show()
  plt.clf()
  plt.close('all')

ranking_over_time(wood, 'El Toro', 'Six Flags Great Adventure')

# %% [markdown]
# 3. Write a function that will plot the ranking of two given roller coasters over time as lines. Your function should take both roller coasters' names and a ranking DataFrame as arguments. Make sure to include informative labels that describe your visualization.
#
#    Call your function with `"El Toro"` as one roller coaster name, `"Boulder Dash"` as the other roller coaster name, and the wood ranking DataFrame. What issue do you notice? Update your function with two additional arguments to alleviate the problem, and retest your function.

# %%
def ranking_two_over_time(my_frame1, my_rollercoaster1, my_park1, my_frame2, my_rollercoaster2, my_park2): 
  my_roller_ranking1 = my_frame1[(my_frame1.Name == my_rollercoaster1) & (my_frame1.Park == my_park1)]
  my_roller_ranking2 = my_frame2[(my_frame2.Name == my_rollercoaster2) & (my_frame2.Park == my_park2)]
  plt.figure(figsize=(15, 8))
  x1 = my_roller_ranking1['Year of Rank']
  y1 = my_roller_ranking1.Points
  x2 = my_roller_ranking2['Year of Rank']
  y2 = my_roller_ranking2.Points  
  
  plt.plot(x1, y1, color='purple', linestyle='--', marker='s')
  plt.plot(x2, y2, color='green', linestyle=':', marker='*')
  sns.set_style('darkgrid')
  plt.xlabel('Year')
  plt.ylabel('Ranking by points')
  plt.title(f'{my_rollercoaster1} and {my_rollercoaster2} ranking over time')
  plt.legend([my_rollercoaster1, my_rollercoaster2])
  plt.show()
  plt.clf()
  plt.close('all')

ranking_two_over_time(wood, 'El Toro', 'Six Flags Great Adventure', wood, 'Boulder Dash', 'Lake Compounce')

# %% [markdown]
# 4. Write a function that will plot the ranking of the top `n` ranked roller coasters over time as lines. Your function should take a number `n` and a ranking DataFrame as arguments. Make sure to include informative labels that describe your visualization.
#
#    For example, if `n == 5`, your function should plot a line for each roller coaster that has a rank of `5` or lower.
#
#    Call your function with a value of `n` and either the wood ranking or steel ranking DataFrame.

# %%
def my_top_rollercoasters(my_frame, my_number): 
    my_number_ranking = my_frame[my_frame.Rank <= my_number]
    fig, ax = plt.subplots(figsize=(15,12))
    
    for rollercoaster in my_number_ranking.Name:
        named_rankings = my_number_ranking[my_number_ranking.Name == rollercoaster]
        plt.plot(named_rankings['Year of Rank'], named_rankings['Rank'], label=rollercoaster)
    
    sns.set_style('whitegrid')
    sns.set_palette('bright') 
    
    ax.set_yticks(range(my_number))
    plt.title(f'Top {my_number} Rankings')
    plt.xlabel('Year')
    plt.ylabel('Ranking')
    plt.legend([rollercoaster for rollercoaster in my_number_ranking.Name], loc=1)
    #plt.legend(list(set(my_number_ranking.Name)), loc=1)
    plt.show()
    plt.close()
    

my_top_rollercoasters(wood, 5)

# %% [markdown]
# 5. Now that you've visualized rankings over time, let's dive into the actual statistics of roller coasters themselves. [Captain Coaster](https://captaincoaster.com/en/) is a popular site for recording roller coaster information. Data on all roller coasters documented on Captain Coaster has been accessed through its API and stored in `roller_coasters.csv`. Load the data from the csv into a DataFrame and inspect it to gain familiarity with the data.

# %%
cc = pd.read_csv('roller_coasters.csv')
cc.head()
# Out:
#             name material_type seating_type  speed  height  length  \
# 0       Goudurix         Steel     Sit Down   75.0    37.0   950.0
# 1  Dream catcher         Steel    Suspended   45.0    25.0   600.0
# 2     Alucinakis         Steel     Sit Down   30.0     8.0   250.0
# 3       Anaconda        Wooden     Sit Down   85.0    35.0  1200.0
# 4         Azteka         Steel     Sit Down   55.0    17.0   500.0
#
#    num_inversions     manufacturer            park            status
# 0             7.0           Vekoma    Parc Asterix  status.operating
# 1             0.0           Vekoma   Bobbejaanland  status.operating
# 2             0.0         Zamperla    Terra Mítica  status.operating
# 3             0.0  William J. Cobb  Walygator Parc  status.operating
# 4             0.0           Soquet          Le Pal  status.operating

# %%
cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2802 entries, 0 to 2801
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            2799 non-null   object
#  1   material_type   2802 non-null   object
#  2   seating_type    2802 non-null   object
#  3   speed           1478 non-null   float64
#  4   height          1667 non-null   float64
#  5   length          1675 non-null   float64
#  6   num_inversions  2405 non-null   float64
#  7   manufacturer    2802 non-null   object
#  8   park            2802 non-null   object
#  9   status          2802 non-null   object
# dtypes: float64(4), object(6)
# memory usage: 219.0+ KB

# %%
cc.describe(include='all')
# Out:
#           name material_type seating_type        speed       height  \
# count     2799          2802         2802  1478.000000  1667.000000
# unique    2075             4           15          NaN          NaN
# top     Dragon         Steel     Sit Down          NaN          NaN
# freq        26          2059         2217          NaN          NaN
# mean       NaN           NaN          NaN    70.102842    26.725855
# std        NaN           NaN          NaN    28.338394    35.010166
# min        NaN           NaN          NaN     0.000000     0.000000
# 25%        NaN           NaN          NaN    47.000000    13.000000
# 50%        NaN           NaN          NaN    72.000000    23.000000
# 75%        NaN           NaN          NaN    88.000000    35.000000
# max        NaN           NaN          NaN   240.000000   902.000000
#
#              length  num_inversions manufacturer   park            status
# count   1675.000000     2405.000000         2802   2802              2802
# unique          NaN             NaN          122    718                 9
# top             NaN             NaN           na  Foire  status.operating
# freq            NaN             NaN          307    121              2172
# mean     606.147463        0.809563          NaN    NaN               NaN
# std      393.840496        1.652254          NaN    NaN               NaN
# min       -1.000000        0.000000          NaN    NaN               NaN
# 25%      335.000000        0.000000          NaN    NaN               NaN
# 50%      500.000000        0.000000          NaN    NaN               NaN
# 75%      839.000000        1.000000          NaN    NaN               NaN
# max     2920.000000       14.000000          NaN    NaN               NaN

# %%
cc.isna().sum()
# Out:
# name                 3
# material_type        0
# seating_type         0
# speed             1324
# height            1135
# length            1127
# num_inversions     397
# manufacturer         0
# park                 0
# status               0
# dtype: int64

# %%
cc[cc.isnull().any(axis=1)]
# Out:
#                                     name material_type seating_type  speed  \
# 10    Casey Jr, le Petit Train du Cirque         Steel     Sit Down   30.0
# 13                         Coleoz'Arbres         Steel     Sit Down   60.0
# 14                                 Comet         Steel     Sit Down   64.0
# 16                               Cumbres         Steel     Sit Down    NaN
# 17                  Le Dragon de Bei Hai         Steel     Sit Down    NaN
# ...                                  ...           ...          ...    ...
# 2796                             Cyclone         Steel     Sit Down    NaN
# 2797                    Dragon Challenge         Steel     Sit Down    NaN
# 2798                          Wild Mouse         Steel     Spinning    NaN
# 2800     Unknown Duelling Launch Coaster         Steel           na    NaN
# 2801                       Black Diamond         Steel     Sit Down    NaN
#
#       height  length  num_inversions                   manufacturer  \
# 10       NaN     NaN             0.0                         Vekoma
# 13       NaN   540.0             0.0                    Schwarzkopf
# 14      24.0     NaN             3.0                         Vekoma
# 16       3.0     NaN             0.0                  Miler Coaster
# 17       NaN     NaN             0.0                  Cavazza Diego
# ...      ...     ...             ...                            ...
# 2796     NaN     NaN             0.0                            SBF
# 2797     NaN     NaN             0.0                        Pinfari
# 2798     NaN     NaN             0.0                      Reverchon
# 2800     NaN     NaN             0.0                             na
# 2801    11.0     NaN             0.0  Philadelphia Toboggan Coaster
#
#                                  park                    status
# 10                    Disneyland Park          status.operating
# 13                          Bagatelle  status.closed.definitely
# 14                     Walygator Parc          status.operating
# 16    Parque de Atracciones de Madrid  status.closed.definitely
# 17                    La Mer de Sable  status.closed.definitely
# ...                               ...                       ...
# 2796       Barry Island Pleasure Park          status.operating
# 2797       Barry Island Pleasure Park          status.operating
# 2798       Barry Island Pleasure Park          status.operating
# 2800        Universal's Epic Universe            status.rumored
# 2801                         Knoebels          status.operating
#
# [1523 rows x 10 columns]

# %%
cc.duplicated().sum()
# Out:
# 8

# %%
cc.drop_duplicates()
# Out:
#                                      name material_type seating_type  speed  \
# 0                                Goudurix         Steel     Sit Down   75.0
# 1                           Dream catcher         Steel    Suspended   45.0
# 2                              Alucinakis         Steel     Sit Down   30.0
# 3                                Anaconda        Wooden     Sit Down   85.0
# 4                                  Azteka         Steel     Sit Down   55.0
# ...                                   ...           ...          ...    ...
# 2797                     Dragon Challenge         Steel     Sit Down    NaN
# 2798                           Wild Mouse         Steel     Spinning    NaN
# 2799  Unnamed Atlantica Supersplash Clone         Steel     Sit Down   80.0
# 2800      Unknown Duelling Launch Coaster         Steel           na    NaN
# 2801                        Black Diamond         Steel     Sit Down    NaN
#
#       height  length  num_inversions                   manufacturer  \
# 0       37.0   950.0             7.0                         Vekoma
# 1       25.0   600.0             0.0                         Vekoma
# 2        8.0   250.0             0.0                       Zamperla
# 3       35.0  1200.0             0.0                William J. Cobb
# 4       17.0   500.0             0.0                         Soquet
# ...      ...     ...             ...                            ...
# 2797     NaN     NaN             0.0                        Pinfari
# 2798     NaN     NaN             0.0                      Reverchon
# 2799    30.0   390.0             0.0                           Mack
# 2800     NaN     NaN             0.0                             na
# 2801    11.0     NaN             0.0  Philadelphia Toboggan Coaster
#
#                             park            status
# 0                   Parc Asterix  status.operating
# 1                  Bobbejaanland  status.operating
# 2                   Terra Mítica  status.operating
# 3                 Walygator Parc  status.operating
# 4                         Le Pal  status.operating
# ...                          ...               ...
# 2797  Barry Island Pleasure Park  status.operating
# 2798  Barry Island Pleasure Park  status.operating
# 2799                      Le Pal  status.announced
# 2800   Universal's Epic Universe    status.rumored
# 2801                    Knoebels  status.operating
#
# [2794 rows x 10 columns]

# %% [markdown]
# 6. Write a function that plots a histogram of any numeric column of the roller coaster DataFrame. Your function should take a DataFrame and a column name for which a histogram should be constructed as arguments. Make sure to include informative labels that describe your visualization.
#
#    Call your function with the roller coaster DataFrame and one of the column names.

# %%
def plot_my_column(frame, column): 
    plt.figure(figsize=(12,6))
    my_bins = round(frame[column].max())

    sns.histplot(data=frame, x=column)
    #plt.hist(frame[column], bins=my_bins, alpha=0.5)
    
    plt.title(f'Histogram of {column}')
    plt.ylabel(f'Number of parks with these {column}(s)')
    plt.xlabel(f'{column}')
    plt.xticks(range(my_bins))
    
    sns.set_style('darkgrid')
    sns.set_palette('dark') 
    
    plt.show()
    plt.clf()
    
plot_my_column(cc, 'num_inversions')

# %%
lots_of_inversions = cc[cc.num_inversions >= 8]

# %%
lots_of_inversions.num_inversions.value_counts()
# Out:
# 8.0     5
# 10.0    5
# 14.0    1
# 9.0     1
# 11.0    1
# Name: num_inversions, dtype: int64

# %% [markdown]
# 7. Write a function that creates a bar chart showing the number of inversions for each roller coaster at an amusement park. Your function should take the roller coaster DataFrame and an amusement park name as arguments. Make sure to include informative labels that describe your visualization.
#
#    Call your function with the roller coaster DataFrame and amusement park name.

# %%
def inversions_per_coaster_per_park(frame, park): 
    plt.figure(figsize=(12,6))

    x = frame.name[frame.park == park]
    y = frame.num_inversions[frame.park == park]
    plt.bar(x, y)
    
    plt.title('Histogram of Inversions per coaster per park')
    plt.xlabel(f'{park}')
    plt.ylabel('Inversions')
    plt.xticks(x, rotation=80)
    plt.yticks()
    
    my_palette = sns.color_palette('Accent', 9)
    sns.set_style('darkgrid')
    sns.set_palette(my_palette)
    
    plt.show()
    plt.close('all')


    
    
inversions_per_coaster_per_park(cc, 'Six Flags Great Adventure')

# %% [markdown]
# 8. Write a function that creates a pie chart that compares the number of operating roller coasters (`'status.operating'`) to the number of closed roller coasters (`'status.closed.definitely'`). Your function should take the roller coaster DataFrame as an argument. Make sure to include informative labels that describe your visualization.
#
#    Call your function with the roller coaster DataFrame.

# %%
# 8
# Create a function to plot a pie chart of status.operating
def operating_or_not(df): 
    plt.figure(figsize=(10,8))
    plt.axis('equal')

    y=[len(df[df.status == 'status.operating']), len(df[df.status == 'status.closed.definitely'])]
    plt.pie(y, autopct='% 0.2f %%', labels=['Currently operating', 'Permanently closed'])

    
    plt.title('Operating Status')
    plt.legend(['Currently operating', 'Permanently closed'])
    my_palette = sns.color_palette('Dark2', 9)
    sns.set_palette(my_palette)
    
    plt.show()
    plt.close('all')

# Create pie chart of roller coasters
operating_or_not(cc)

# %% [markdown]
# 9. `.scatter()` is another useful function in matplotlib that you might not have seen before. `.scatter()` produces a scatter plot, which is similar to `.plot()` in that it plots points on a figure. `.scatter()`, however, does not connect the points with a line. This allows you to analyze the relationship between two variables. Find [`.scatter()`'s documentation here](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html).
#
#    Write a function that creates a scatter plot of two numeric columns of the roller coaster DataFrame. Your function should take the roller coaster DataFrame and two-column names as arguments. Make sure to include informative labels that describe your visualization.
#
#    Call your function with the roller coaster DataFrame and two-column names.

# %%
cc2 = cc[(cc.speed > 0) & (cc.speed < 200)]
cc2 = cc[(cc.height > 0) & (cc.height < 200)]

# %%
cc2
# Out:
#                                      name material_type seating_type  speed  \
# 0                                Goudurix         Steel     Sit Down   75.0
# 1                           Dream catcher         Steel    Suspended   45.0
# 2                              Alucinakis         Steel     Sit Down   30.0
# 3                                Anaconda        Wooden     Sit Down   85.0
# 4                                  Azteka         Steel     Sit Down   55.0
# ...                                   ...           ...          ...    ...
# 2767                               Legend        Wooden           na    NaN
# 2771                           Cork Screw            na           na    NaN
# 2773                     Yagiyama Cyclone            na           na    NaN
# 2799  Unnamed Atlantica Supersplash Clone         Steel     Sit Down   80.0
# 2801                        Black Diamond         Steel     Sit Down    NaN
#
#       height  length  num_inversions                   manufacturer  \
# 0       37.0   950.0             7.0                         Vekoma
# 1       25.0   600.0             0.0                         Vekoma
# 2        8.0   250.0             0.0                       Zamperla
# 3       35.0  1200.0             0.0                William J. Cobb
# 4       17.0   500.0             0.0                         Soquet
# ...      ...     ...             ...                            ...
# 2767    19.0     NaN             0.0                             na
# 2771    21.0   366.0             2.0                          Arrow
# 2773    17.0   600.0             0.0                             na
# 2799    30.0   390.0             0.0                           Mack
# 2801    11.0     NaN             0.0  Philadelphia Toboggan Coaster
#
#                 park            status
# 0       Parc Asterix  status.operating
# 1      Bobbejaanland  status.operating
# 2       Terra Mítica  status.operating
# 3     Walygator Parc  status.operating
# 4             Le Pal  status.operating
# ...              ...               ...
# 2767    Arnolds Park  status.operating
# 2771        Benyland  status.operating
# 2773        Benyland  status.operating
# 2799          Le Pal  status.announced
# 2801        Knoebels  status.operating
#
# [1650 rows x 10 columns]

# %%
def scatter_me(df, column1, column2): 
    plt.figure(figsize=(14,8))
    
    sns.scatterplot(x=column1, y=column2, data=df, hue='speed', style='material_type')
    
    sns.set_style('whitegrid') # whitegrid / dark / white / ticks
    sns.set_palette('bright') # muted / pastel / bright / dark / colorblind
    
    plt.title(f'Scatterplot of {column1} and {column2}')
    plt.show()
    plt.close('all')    


scatter_me(cc2, 'speed', 'height')
